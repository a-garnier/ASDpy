# %% [markdown]
# <h1>Generate folders + Convert wav to spectrograms for the cnn v2 model</h1>

# %%
"""
    Convert wavs from data_origin/[machine] to color spectrograms into folders
    # construct dataset of images spectrogram (normal only) in folders:
        # data_png_cnn2/machines/[machine]
        # data_png_cnn2/all_png_test is used for images tests never seen by the model (1000 normal of each class & all anormal images)

"""
from os import listdir
from os.path import isfile, join
import numpy as np
import sys
import datetime
import shutil



# add parent folder to path 
from pathlib import Path
path = Path(os.getcwd())
str_parent = str(path.parent.absolute())
if not str_parent in sys.path:
    sys.path.append(str_parent)
import utils 
from SoundFile import SoundFile

# %%
nbImagesTotestEachClass = 1000 # put this count of images in all_png_test_v5 (for each class)
start_time = datetime.datetime.now()
dictStat = {'normal': 0, 'anomaly': 0} # stats count of files in 2 classes

 
# create folders in order to export pngs files (remove all previous png) -> _data_png_cnn2/[machine]
mode = 0o777
cwd = os.getcwd() 
path = Path(cwd)

png_root_folder = str(path.parent.parent.absolute()) + '/_data_png_cnn2'
model_root_folder = str(path.parent.parent.absolute()) + '/_classifier_cnn2'

# %%
# delete old folders if needed
try:
    shutil.rmtree(png_root_folder)
except OSError as e:
    print ("folder not found: %s - %s." % (e.filename, e.strerror))

try:
    shutil.rmtree(model_root_folder)
except OSError as e:
    print ("folder not found: %s - %s." % (e.filename, e.strerror))

os.mkdir(os.path.join(png_root_folder), mode)
print ("folder created: %s." % png_root_folder)
os.mkdir(os.path.join(model_root_folder), mode)
print ("folder created: %s." % model_root_folder)

os.mkdir(os.path.join(png_root_folder + '/all_png_test'), mode)
os.mkdir(os.path.join(png_root_folder + '/machines'), mode)

for folder_machine in utils.list_datasets: # ['valve']    
    os.mkdir(os.path.join(png_root_folder + '/machines/' + folder_machine), mode)
# Out:
# folder created: /Users/david/DEVS_LOCAL/dev-ia-son/partage-ia-son/_data_png_cnn2.
# folder created: /Users/david/DEVS_LOCAL/dev-ia-son/partage-ia-son/_classifier_cnn2.

# %%
out_folder_png_test = '../../_data_png_cnn2/all_png_test/'

for folder_machine in utils.list_datasets: # ['valve']
    for n in ['train', 'test']:    
        use_folder = '../../_data_origin/' + folder_machine + '/' + n + '/' 
        wavfiles = [f for f in listdir(use_folder) if isfile(join(use_folder, f))]
        if '.DS_Store' in wavfiles:
            wavfiles.remove('.DS_Store')
        
        nbWavs = len(wavfiles)
        countImages =  0    # counter for all images
        countImagesNormal =  0   
         
         # count files in each class
        for f in wavfiles:
            arrName = f.split("_") # anomaly_id_00_00000001.wav
            classPrefix = arrName[0] # 'normal' or 'anomaly'
            dictStat['normal'] =  dictStat['normal'] + 1 if classPrefix == 'normal' else dictStat['normal']

        # random choose of images for testing at the end: put them in png_test folder_machine
        arrIndicesImagesToTestNormal = np.random.randint(1, dictStat['normal'], nbImagesTotestEachClass) 

        for f in wavfiles:
            arrName = f.split("_") # anomaly_id_00_00000001.wav
            out_folder_png = ''
            classPrefix = arrName[0] # 'normal' or 'anomaly'
            out_folder_png = '../../_data_png_cnn2/machines/' + folder_machine + '/'
            
            countImages += 1
            if classPrefix == 'normal':
                countImagesNormal += 1

            # use some anomaly for the training set:
            if classPrefix == 'normal' and countImagesNormal in arrIndicesImagesToTestNormal or classPrefix == 'anomaly':
                out_folder_png = out_folder_png_test
            
            if countImages % 100 == 0:
                print('countImages generated...: ', countImages, ' / ', nbWavs, '(', folder_machine, ')')
        
            # print('use_folder: ', use_folder + f, out_folder_png, folder_machine)
            s = SoundFile(use_folder + f, out_folder_png, folder_machine)
            s.exportMelSpectrogramColor() # create color file    

now = datetime.datetime.now()
print("*************** End ******************", now.strftime("%Y-%m-%d %H:%M:%S"))
# Out:
# dictStat:  {'normal': 9873, 'anomaly': 0}
# countImages generated...:  100  /  3291 ( valve )
# countImages generated...:  200  /  3291 ( valve )
# countImages generated...:  300  /  3291 ( valve )
# countImages generated...:  400  /  3291 ( valve )
# countImages generated...:  500  /  3291 ( valve )
# countImages generated...:  600  /  3291 ( valve )
# countImages generated...:  700  /  3291 ( valve )
# countImages generated...:  800  /  3291 ( valve )
# countImages generated...:  900  /  3291 ( valve )
# countImages generated...:  1000  /  3291 ( valve )
# countImages generated...:  1100  /  3291 ( valve )
# countImages generated...:  1200  /  3291 ( valve )
# countImages generated...:  1300  /  3291 ( valve )
# countImages generated...:  1400  /  3291 ( valve )
# countImages generated...:  1500  /  3291 ( valve )
# countImages generated...:  1600  /  3291 ( valve )
# countImages generated...:  1700  /  3291 ( valve )
# countImages generated...:  1800  /  3291 ( valve )
# countImages generated...:  1900  /  3291 ( valve )
# countImages generated...:  2000  /  3291 ( valve )
# countImages generated...:  2100  /  3291 ( valve )
# countImages generated...:  2200  /  3291 ( valve )
# countImages generated...:  2300  /  3291 ( valve )
# countImages generated...:  2400  /  3291 ( valve )
# countImages generated...:  2500  /  3291 ( valve )
# countImages generated...:  2600  /  3291 ( valve )
# countImages generated...:  2700  /  3291 ( valve )
# countImages generated...:  2800  /  3291 ( valve )
# countImages generated...:  2900  /  3291 ( valve )
# countImages generated...:  3000  /  3291 ( valve )
# countImages generated...:  3100  /  3291 ( valve )
# countImages generated...:  3200  /  3291 ( valve )
# dictStat:  {'normal': 10273, 'anomaly': 0}
# countImages generated...:  100  /  879 ( valve )
# countImages generated...:  200  /  879 ( valve )
# countImages generated...:  300  /  879 ( valve )
# countImages generated...:  400  /  879 ( valve )
# countImages generated...:  500  /  879 ( valve )
# countImages generated...:  600  /  879 ( valve )
# countImages generated...:  700  /  879 ( valve )
# countImages generated...:  800  /  879 ( valve )
# dictStat:  {'normal': 13077, 'anomaly': 0}
# countImages generated...:  100  /  2804 ( slider )
# countImages generated...:  200  /  2804 ( slider )
# countImages generated...:  300  /  2804 ( slider )
# countImages generated...:  400  /  2804 ( slider )
# countImages generated...:  500  /  2804 ( slider )
# countImages generated...:  600  /  2804 ( slider )
# countImages generated...:  700  /  2804 ( slider )
# countImages generated...:  800  /  2804 ( slider )
# countImages generated...:  900  /  2804 ( slider )
# countImages generated...:  1000  /  2804 ( slider )
# countImages generated...:  1100  /  2804 ( slider )
# countImages generated...:  1200  /  2804 ( slider )
# countImages generated...:  1300  /  2804 ( slider )
# countImages generated...:  1400  /  2804 ( slider )
# countImages generated...:  1500  /  2804 ( slider )
# countImages generated...:  1600  /  2804 ( slider )
# countImages generated...:  1700  /  2804 ( slider )
# countImages generated...:  1800  /  2804 ( slider )
# countImages generated...:  1900  /  2804 ( slider )
# countImages generated...:  2000  /  2804 ( slider )
# countImages generated...:  2100  /  2804 ( slider )
# countImages generated...:  2200  /  2804 ( slider )
# countImages generated...:  2300  /  2804 ( slider )
# countImages generated...:  2400  /  2804 ( slider )
# countImages generated...:  2500  /  2804 ( slider )
# countImages generated...:  2600  /  2804 ( slider )
# countImages generated...:  2700  /  2804 ( slider )
# countImages generated...:  2800  /  2804 ( slider )
# dictStat:  {'normal': 13477, 'anomaly': 0}
# countImages generated...:  100  /  1290 ( slider )
# countImages generated...:  200  /  1290 ( slider )
# countImages generated...:  300  /  1290 ( slider )
# countImages generated...:  400  /  1290 ( slider )
# countImages generated...:  500  /  1290 ( slider )
# countImages generated...:  600  /  1290 ( slider )
# countImages generated...:  700  /  1290 ( slider )
# countImages generated...:  800  /  1290 ( slider )
# countImages generated...:  900  /  1290 ( slider )
# countImages generated...:  1000  /  1290 ( slider )
# countImages generated...:  1100  /  1290 ( slider )
# countImages generated...:  1200  /  1290 ( slider )
# dictStat:  {'normal': 16826, 'anomaly': 0}
# countImages generated...:  100  /  3349 ( pump )
# countImages generated...:  200  /  3349 ( pump )
# countImages generated...:  300  /  3349 ( pump )
# countImages generated...:  400  /  3349 ( pump )
# countImages generated...:  500  /  3349 ( pump )
# countImages generated...:  600  /  3349 ( pump )
# countImages generated...:  700  /  3349 ( pump )
# countImages generated...:  800  /  3349 ( pump )
# countImages generated...:  900  /  3349 ( pump )
# countImages generated...:  1000  /  3349 ( pump )
# countImages generated...:  1100  /  3349 ( pump )
# countImages generated...:  1200  /  3349 ( pump )
# countImages generated...:  1300  /  3349 ( pump )
# countImages generated...:  1400  /  3349 ( pump )
# countImages generated...:  1500  /  3349 ( pump )
# countImages generated...:  1600  /  3349 ( pump )
# countImages generated...:  1700  /  3349 ( pump )
# countImages generated...:  1800  /  3349 ( pump )
# countImages generated...:  1900  /  3349 ( pump )
# countImages generated...:  2000  /  3349 ( pump )
# countImages generated...:  2100  /  3349 ( pump )
# countImages generated...:  2200  /  3349 ( pump )
# countImages generated...:  2300  /  3349 ( pump )
# countImages generated...:  2400  /  3349 ( pump )
# countImages generated...:  2500  /  3349 ( pump )
# countImages generated...:  2600  /  3349 ( pump )
# countImages generated...:  2700  /  3349 ( pump )
# countImages generated...:  2800  /  3349 ( pump )
# countImages generated...:  2900  /  3349 ( pump )
# countImages generated...:  3000  /  3349 ( pump )
# countImages generated...:  3100  /  3349 ( pump )
# countImages generated...:  3200  /  3349 ( pump )
# countImages generated...:  3300  /  3349 ( pump )
# dictStat:  {'normal': 17226, 'anomaly': 0}
# countImages generated...:  100  /  856 ( pump )
# countImages generated...:  200  /  856 ( pump )
# countImages generated...:  300  /  856 ( pump )
# countImages generated...:  400  /  856 ( pump )
# countImages generated...:  500  /  856 ( pump )
# countImages generated...:  600  /  856 ( pump )
# countImages generated...:  700  /  856 ( pump )
# countImages generated...:  800  /  856 ( pump )
# dictStat:  {'normal': 21226, 'anomaly': 0}
# countImages generated...:  100  /  4000 ( ToyCar )
# countImages generated...:  200  /  4000 ( ToyCar )
# countImages generated...:  300  /  4000 ( ToyCar )
# countImages generated...:  400  /  4000 ( ToyCar )
# countImages generated...:  500  /  4000 ( ToyCar )
# countImages generated...:  600  /  4000 ( ToyCar )
# countImages generated...:  700  /  4000 ( ToyCar )
# countImages generated...:  800  /  4000 ( ToyCar )
# countImages generated...:  900  /  4000 ( ToyCar )
# countImages generated...:  1000  /  4000 ( ToyCar )
# countImages generated...:  1100  /  4000 ( ToyCar )
# countImages generated...:  1200  /  4000 ( ToyCar )
# countImages generated...:  1300  /  4000 ( ToyCar )
# countImages generated...:  1400  /  4000 ( ToyCar )
# countImages generated...:  1500  /  4000 ( ToyCar )
# countImages generated...:  1600  /  4000 ( ToyCar )
# countImages generated...:  1700  /  4000 ( ToyCar )
# countImages generated...:  1800  /  4000 ( ToyCar )
# countImages generated...:  1900  /  4000 ( ToyCar )
# countImages generated...:  2000  /  4000 ( ToyCar )
# countImages generated...:  2100  /  4000 ( ToyCar )
# countImages generated...:  2200  /  4000 ( ToyCar )
# countImages generated...:  2300  /  4000 ( ToyCar )
# countImages generated...:  2400  /  4000 ( ToyCar )
# countImages generated...:  2500  /  4000 ( ToyCar )
# countImages generated...:  2600  /  4000 ( ToyCar )
# countImages generated...:  2700  /  4000 ( ToyCar )
# countImages generated...:  2800  /  4000 ( ToyCar )
# countImages generated...:  2900  /  4000 ( ToyCar )
# countImages generated...:  3000  /  4000 ( ToyCar )
# countImages generated...:  3100  /  4000 ( ToyCar )
# countImages generated...:  3200  /  4000 ( ToyCar )
# countImages generated...:  3300  /  4000 ( ToyCar )
# countImages generated...:  3400  /  4000 ( ToyCar )
# countImages generated...:  3500  /  4000 ( ToyCar )
# countImages generated...:  3600  /  4000 ( ToyCar )
# countImages generated...:  3700  /  4000 ( ToyCar )
# countImages generated...:  3800  /  4000 ( ToyCar )
# countImages generated...:  3900  /  4000 ( ToyCar )
# countImages generated...:  4000  /  4000 ( ToyCar )
# dictStat:  {'normal': 22626, 'anomaly': 0}
# countImages generated...:  100  /  2459 ( ToyCar )
# countImages generated...:  200  /  2459 ( ToyCar )
# countImages generated...:  300  /  2459 ( ToyCar )
# countImages generated...:  400  /  2459 ( ToyCar )
# countImages generated...:  500  /  2459 ( ToyCar )
# countImages generated...:  600  /  2459 ( ToyCar )
# countImages generated...:  700  /  2459 ( ToyCar )
# countImages generated...:  800  /  2459 ( ToyCar )
# countImages generated...:  900  /  2459 ( ToyCar )
# countImages generated...:  1000  /  2459 ( ToyCar )
# countImages generated...:  1100  /  2459 ( ToyCar )
# countImages generated...:  1200  /  2459 ( ToyCar )
# countImages generated...:  1300  /  2459 ( ToyCar )
# countImages generated...:  1400  /  2459 ( ToyCar )
# countImages generated...:  1500  /  2459 ( ToyCar )
# countImages generated...:  1600  /  2459 ( ToyCar )
# countImages generated...:  1700  /  2459 ( ToyCar )
# countImages generated...:  1800  /  2459 ( ToyCar )
# countImages generated...:  1900  /  2459 ( ToyCar )
# countImages generated...:  2000  /  2459 ( ToyCar )
# countImages generated...:  2100  /  2459 ( ToyCar )
# countImages generated...:  2200  /  2459 ( ToyCar )
# countImages generated...:  2300  /  2459 ( ToyCar )
# countImages generated...:  2400  /  2459 ( ToyCar )
# dictStat:  {'normal': 26301, 'anomaly': 0}
# countImages generated...:  100  /  3675 ( fan )
# countImages generated...:  200  /  3675 ( fan )
# countImages generated...:  300  /  3675 ( fan )
# countImages generated...:  400  /  3675 ( fan )
# countImages generated...:  500  /  3675 ( fan )
# countImages generated...:  600  /  3675 ( fan )
# countImages generated...:  700  /  3675 ( fan )
# countImages generated...:  800  /  3675 ( fan )
# countImages generated...:  900  /  3675 ( fan )
# countImages generated...:  1000  /  3675 ( fan )
# countImages generated...:  1100  /  3675 ( fan )
# countImages generated...:  1200  /  3675 ( fan )
# countImages generated...:  1300  /  3675 ( fan )
# countImages generated...:  1400  /  3675 ( fan )
# countImages generated...:  1500  /  3675 ( fan )
# countImages generated...:  1600  /  3675 ( fan )
# countImages generated...:  1700  /  3675 ( fan )
# countImages generated...:  1800  /  3675 ( fan )
# countImages generated...:  1900  /  3675 ( fan )
# countImages generated...:  2000  /  3675 ( fan )
# countImages generated...:  2100  /  3675 ( fan )
# countImages generated...:  2200  /  3675 ( fan )
# countImages generated...:  2300  /  3675 ( fan )
# countImages generated...:  2400  /  3675 ( fan )
# countImages generated...:  2500  /  3675 ( fan )
# countImages generated...:  2600  /  3675 ( fan )
# countImages generated...:  2700  /  3675 ( fan )
# countImages generated...:  2800  /  3675 ( fan )
# countImages generated...:  2900  /  3675 ( fan )
# countImages generated...:  3000  /  3675 ( fan )
# countImages generated...:  3100  /  3675 ( fan )
# countImages generated...:  3200  /  3675 ( fan )
# countImages generated...:  3300  /  3675 ( fan )
# countImages generated...:  3400  /  3675 ( fan )
# countImages generated...:  3500  /  3675 ( fan )
# countImages generated...:  3600  /  3675 ( fan )
# dictStat:  {'normal': 26701, 'anomaly': 0}
# countImages generated...:  100  /  1875 ( fan )
# countImages generated...:  200  /  1875 ( fan )
# countImages generated...:  300  /  1875 ( fan )
# countImages generated...:  400  /  1875 ( fan )
# countImages generated...:  500  /  1875 ( fan )
# countImages generated...:  600  /  1875 ( fan )
# countImages generated...:  700  /  1875 ( fan )
# countImages generated...:  800  /  1875 ( fan )
# countImages generated...:  900  /  1875 ( fan )
# countImages generated...:  1000  /  1875 ( fan )
# countImages generated...:  1100  /  1875 ( fan )
# countImages generated...:  1200  /  1875 ( fan )
# countImages generated...:  1300  /  1875 ( fan )
# countImages generated...:  1400  /  1875 ( fan )
# countImages generated...:  1500  /  1875 ( fan )
# countImages generated...:  1600  /  1875 ( fan )
# countImages generated...:  1700  /  1875 ( fan )
# countImages generated...:  1800  /  1875 ( fan )
# dictStat:  {'normal': 29701, 'anomaly': 0}
# countImages generated...:  100  /  3000 ( ToyConveyor )
# countImages generated...:  200  /  3000 ( ToyConveyor )
# countImages generated...:  300  /  3000 ( ToyConveyor )
# countImages generated...:  400  /  3000 ( ToyConveyor )
# countImages generated...:  500  /  3000 ( ToyConveyor )
# countImages generated...:  600  /  3000 ( ToyConveyor )
# countImages generated...:  700  /  3000 ( ToyConveyor )
# countImages generated...:  800  /  3000 ( ToyConveyor )
# countImages generated...:  900  /  3000 ( ToyConveyor )
# countImages generated...:  1000  /  3000 ( ToyConveyor )
# countImages generated...:  1100  /  3000 ( ToyConveyor )
# countImages generated...:  1200  /  3000 ( ToyConveyor )
# countImages generated...:  1300  /  3000 ( ToyConveyor )
# countImages generated...:  1400  /  3000 ( ToyConveyor )
# countImages generated...:  1500  /  3000 ( ToyConveyor )
# countImages generated...:  1600  /  3000 ( ToyConveyor )
# countImages generated...:  1700  /  3000 ( ToyConveyor )
# countImages generated...:  1800  /  3000 ( ToyConveyor )
# countImages generated...:  1900  /  3000 ( ToyConveyor )
# countImages generated...:  2000  /  3000 ( ToyConveyor )
# countImages generated...:  2100  /  3000 ( ToyConveyor )
# countImages generated...:  2200  /  3000 ( ToyConveyor )
# countImages generated...:  2300  /  3000 ( ToyConveyor )
# countImages generated...:  2400  /  3000 ( ToyConveyor )
# countImages generated...:  2500  /  3000 ( ToyConveyor )
# countImages generated...:  2600  /  3000 ( ToyConveyor )
# countImages generated...:  2700  /  3000 ( ToyConveyor )
# countImages generated...:  2800  /  3000 ( ToyConveyor )
# countImages generated...:  2900  /  3000 ( ToyConveyor )
# countImages generated...:  3000  /  3000 ( ToyConveyor )
# dictStat:  {'normal': 32100, 'anomaly': 0}
# countImages generated...:  100  /  3509 ( ToyConveyor )
# countImages generated...:  200  /  3509 ( ToyConveyor )
# countImages generated...:  300  /  3509 ( ToyConveyor )
# countImages generated...:  400  /  3509 ( ToyConveyor )
# countImages generated...:  500  /  3509 ( ToyConveyor )
# countImages generated...:  600  /  3509 ( ToyConveyor )
# countImages generated...:  700  /  3509 ( ToyConveyor )
# countImages generated...:  800  /  3509 ( ToyConveyor )
# countImages generated...:  900  /  3509 ( ToyConveyor )
# countImages generated...:  1000  /  3509 ( ToyConveyor )
# countImages generated...:  1100  /  3509 ( ToyConveyor )
# countImages generated...:  1200  /  3509 ( ToyConveyor )
# countImages generated...:  1300  /  3509 ( ToyConveyor )
# countImages generated...:  1400  /  3509 ( ToyConveyor )
# countImages generated...:  1500  /  3509 ( ToyConveyor )
# countImages generated...:  1600  /  3509 ( ToyConveyor )
# countImages generated...:  1700  /  3509 ( ToyConveyor )
# countImages generated...:  1800  /  3509 ( ToyConveyor )
# countImages generated...:  1900  /  3509 ( ToyConveyor )
# countImages generated...:  2000  /  3509 ( ToyConveyor )
# countImages generated...:  2100  /  3509 ( ToyConveyor )
# countImages generated...:  2200  /  3509 ( ToyConveyor )
# countImages generated...:  2300  /  3509 ( ToyConveyor )
# countImages generated...:  2400  /  3509 ( ToyConveyor )
# countImages generated...:  2500  /  3509 ( ToyConveyor )
# countImages generated...:  2600  /  3509 ( ToyConveyor )
# countImages generated...:  2700  /  3509 ( ToyConveyor )
# countImages generated...:  2800  /  3509 ( ToyConveyor )
# countImages generated...:  2900  /  3509 ( ToyConveyor )
# countImages generated...:  3000  /  3509 ( ToyConveyor )
# countImages generated...:  3100  /  3509 ( ToyConveyor )
# countImages generated...:  3200  /  3509 ( ToyConveyor )
# countImages generated...:  3300  /  3509 ( ToyConveyor )
# countImages generated...:  3400  /  3509 ( ToyConveyor )
# countImages generated...:  3500  /  3509 ( ToyConveyor )
# *************** End ****************** 2021-11-11 19:58:14
